# %%
import logging

logging.basicConfig(level=logging.INFO)

# %%
from asset_manager.dashboard import make_charts
# Out:
# /Users/eswan18/Develop/asset_manager/asset_manager/s3.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
make_charts()
# Out:
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials
# alt.VConcatChart(...)

# %%
from asset_manager.datastore import get_all_data

# %%
df = get_all_data()
df
