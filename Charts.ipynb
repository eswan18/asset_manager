# %%
from asset_manager.dashboard import make_charts

# %%
make_charts()
# Out:
# /Users/eswan18/Develop/old_asset_manager/asset_manager/asset_manager/dashboard.py:54: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   assets_by_day = asset_data.groupby("Date", as_index=False)[["Date", "Amount"]].sum()
# /Users/eswan18/Develop/old_asset_manager/asset_manager/asset_manager/dashboard.py:58: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   .sum()
# ...

# %%
from asset_manager.dashboard import get_summary_data

# %%
df = get_summary_data()
df
# Out:
#    Accessible                                  Description     Amount  \
# 0           Y                     Savings Account (PNC VW)       0.14
# 1           Y                    Checking Account (PNC VW)    9580.73
# 2           Y               Charles Schwab Trading Account  110647.87
# 3           Y              Coinbase Cryptocurrency Account    5487.23
# 4           N                                         401k   79066.35
# ..        ...                                          ...        ...
# 10          Y                            Apple Credit Card    3952.67
# 11          Y      Expected Freelance Income Tax Liability       0.00
# 12          Y    Expected Cap Gains Tax Liability (Schwab)    2835.63
# 13          Y  Expected Cap Gains Tax Liability (Fidelity)     148.39
# 14          Y          Expected Deferred Income Tax (401k)    7407.43
#
#     Precision (+/-)       Type       Date
# 0              0.00      asset 2021-01-29
# ...
